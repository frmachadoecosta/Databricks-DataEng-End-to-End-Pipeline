# %%
df = spark.read.table("databricks_cat.bronze.regions")
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@fmcdatabrickse2e.dfs.core.windows.net/regions")

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_cat.silver.regions_silver
USING DELTA
LOCATION 'abfss://silver@fmcdatabrickse2e.dfs.core.windows.net/regions'
